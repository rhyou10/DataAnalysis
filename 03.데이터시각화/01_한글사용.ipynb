# %% [markdown]
# # Matplotlib 에서 한글폰트 사용하기

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Colab 환경

# %%
plt.title('플롯 예')
plt.plot([0, 1, 4, 9])
plt.show()

# %% [markdown]
# ### 1. 한글폰트 설치

# %%
##!apt -get install -y fonts-nanum > /dev/null
##!fc-cache -fv > /dev/null
##!rm -rf ~/.cache/mathplotlib > /dev/null 
#/dev/null 출력하지말고 실행만 해라

# %% [markdown]
# ### 2. runtime 다시시작(반드시)

# %%
# 런타임 다시시작 후
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# minus 표시
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')
'''
#한글 안깨진다

# %% [markdown]
# ## 2 로컬에서 Jupyther Notebook 사용시

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# minus 표시 
# 한글 쓸때 필수다
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# %%
plt.title('플롯 예')
plt.plot([0, 1, 4, 9])
plt.show()
